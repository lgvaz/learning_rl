# %%
import gym
import numpy as np
import tensorflow as tf
import tensorflow.contrib.slim as slim

from skimage.transform import resize
from skimage.color import rgb2gray

import itertools

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = gym.make('Pong-v0')
VALID_ACTIONS = [2, 3]
NUM_ACTIONS = len(VALID_ACTIONS)
# Out:
# [2017-01-08 19:16:40,359] Making new env: Pong-v0

# %%
def preprocess(img):
    return resize(rgb2gray(img), (84, 84))

# %%
def preprocess(I):
    """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
    I = I[35:195] # crop
    I = I[::2,::2,0] # downsample by factor of 2
    I[I == 144] = 0 # erase background (background type 1)
    I[I == 109] = 0 # erase background (background type 2)
    I[I != 0] = 1 # everything else (paddles, ball) just set to 1
    return I

# %%
def shared_network(inputs, reuse):
    '''
    Builds 2 convolutional layers and a fully connected layer at the end
    
    Args:
        inputs: Input image for the network 
    
    Returns:
        The last convolutional layer and the fully connect layer
    '''
    with tf.variable_scope('shared', reuse=reuse):
        # Convolutional layers
        conv = slim.stack(inputs, slim.conv2d, [
                (16, 8, 4),
                (32, 4, 3)
            ])

        # Fully connected layer
        flatten = slim.flatten(conv)
        fc = slim.fully_connected(flatten, 216)
        
        return conv, fc

# %%
class Policy:
    def __init__(self, learning_rate, reuse=False):
        # Placeholders
        self.states = tf.placeholder(name='states',
                                     shape=(None, 80, 80),
                                     dtype=tf.float32)
        self.returns = tf.placeholder(name='returns',
                                      shape=(None),
                                      dtype=tf.float32)
        self.actions = tf.placeholder(name='chosen_action',
                                      shape=(None),
                                      dtype=tf.int32)

        # Create shared network
        self.conv, self.fc = shared_network(self.states, reuse)
        with tf.variable_scope('policy'):
            # Final/output layer
            self.output = slim.fully_connected(self.fc,
                                               NUM_ACTIONS,
                                               activation_fn=tf.nn.softmax)        
        
        # Optimization process (to increase likelihood of a good action)
        batch_size = tf.shape(self.states)[0]
        # Select the ids of picked actions
        # action_ids = (i_batch * NUM_ACTIONS) + action
        action_ids = tf.range(batch_size) * tf.shape(self.output)[1] + self.actions
        # Select probability of chosen actions
        chosen_actions = tf.gather(tf.reshape(self.output, [-1]), action_ids)
        eligibility = tf.log(chosen_actions)
        # Change the likelihood of taken action using the return (self.returns)        
        self.loss = - tf.reduce_mean(self.returns * eligibility)
        opt = tf.train.AdamOptimizer(learning_rate)
        # We should perform gradient ascent in the likelihood of specified action
        # which is the same as performing gradient descent on the negative of the loss
        local_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'policy') \
                     + tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'shared') 
        grads_and_vars = opt.compute_gradients(self.loss, local_vars)
        self.global_step = slim.get_or_create_global_step()
        self.train_op = opt.apply_gradients(grads_and_vars, self.global_step)        
        
    def predict(self, sess, states):
        return sess.run(self.output, feed_dict={self.states: states})
    
    def update(self, sess, states, actions, returns):
        feed_dict = {self.states: states,
                     self.actions: actions,
                     self.returns: returns}
        sess.run(self.train_op, feed_dict=feed_dict)

# %%
def test_updates(learning_rate, batch_size=100):
    ''' Test if the weigth updates are giving the desired outputs '''
    # Create a new policy
    tf.reset_default_graph()
    policy = Policy(learning_rate=learning_rate)
    # Generate states
    state = np.random.random((batch_size, 80, 80))
    fake_returns = [(100, 'increase'), (-100, 'decrease')]
    for action in range(NUM_ACTIONS):
        actions = action * np.ones(batch_size)
        for fake_return, expected in fake_returns:
            # Reinitialize session because ADAM optimizer builds momentum
            with tf.Session() as sess:
                tf.global_variables_initializer().run()
                # Compare new and old probabilities
                old_probs = policy.predict(sess, state)
                policy.update(sess, state, actions, [fake_return])
                new_probs = policy.predict(sess, state)        
                print('Action {} probability should {}:'.format(action, expected), end=' ')
                print(np.mean(new_probs - old_probs, axis=0))

# %%
test_updates(3e-4)
# Out:
# /home/quazar/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:91: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Action 0 probability should increase: [ 0.04927379 -0.0492738 ]
# Action 0 probability should decrease: [-0.05674707  0.05674708]
# Action 1 probability should increase: [-0.05092872  0.05092873]
# Action 1 probability should decrease: [ 0.04037581 -0.04037582]

# %%
class ValueNet:
    def __init__(self, learning_rate, reuse=False):
        # Placeholders
        self.states = tf.placeholder(name='states',
                                     shape=(None, 80, 80),
                                     dtype=tf.float32)
        # TD targets
        self.targets = tf.placeholder(name='targets',
                                      shape=(None),
                                      dtype=tf.float32)
        
        # Get or create shared network
        self.conv, self.fc = shared_network(self.states, reuse)
        # Final/output layer
        with tf.variable_scope('value_net'):
            self.output = slim.fully_connected(inputs=self.fc,
                                               num_outputs=1,
                                               activation_fn=None)
        
        # Loss (mean squared error)
        self.loss = tf.reduce_mean(tf.squared_difference(self.targets, self.output))
        opt = tf.train.AdamOptimizer(learning_rate)
        local_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'value_net') \
                   + tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'shared') 
        grads_and_vars = opt.compute_gradients(self.loss, local_vars)
        self.global_step = slim.get_or_create_global_step()
        self.train_op = opt.apply_gradients(grads_and_vars, self.global_step)        
        
    def predict(self, sess, states):
        return sess.run(self.output, feed_dict={self.states: states})
    
    def update(self, sess, states, targets):
        feed_dict = {self.states: states,
                     self.targets: targets}
        sess.run(self.train_op, feed_dict=feed_dict)

# %%
tf.reset_default_graph()
policy = Policy(3e-4)
baseline = ValueNet(3e-4, True)
# Out:
# /home/quazar/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:91: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
g = tf.get_default_graph()
[op.name for op in g.get_operations()]
# Out:
# ['states',
#  'returns',
#  'chosen_action',
#  'shared/Stack/convolution_1/weights',
#  'shared/Stack/convolution_1/weights/Initializer/random_uniform/shape',
#  'shared/Stack/convolution_1/weights/Initializer/random_uniform/min',
#  'shared/Stack/convolution_1/weights/Initializer/random_uniform/max',
#  'shared/Stack/convolution_1/weights/Initializer/random_uniform/RandomUniform',
#  'shared/Stack/convolution_1/weights/Initializer/random_uniform/sub',
#  'shared/Stack/convolution_1/weights/Initializer/random_uniform/mul',
#  'shared/Stack/convolution_1/weights/Initializer/random_uniform',
#  'shared/Stack/convolution_1/weights/Assign',
#  'shared/Stack/convolution_1/weights/read',
#  'shared/Stack/convolution_1/convolution/Shape',
#  'shared/Stack/convolution_1/convolution/dilation_rate',
#  'shared/Stack/convolution_1/convolution/ExpandDims/dim',
#  'shared/Stack/convolution_1/convolution/ExpandDims',
#  'shared/Stack/convolution_1/convolution/ExpandDims_1/dim',
#  'shared/Stack/convolution_1/convolution/ExpandDims_1',
#  'shared/Stack/convolution_1/convolution/Conv2D',
#  'shared/Stack/convolution_1/convolution/Squeeze',
#  'shared/Stack/convolution_1/biases',
#  'shared/Stack/convolution_1/biases/Initializer/zeros',
#  'shared/Stack/convolution_1/biases/Assign',
#  'shared/Stack/convolution_1/biases/read',
#  'shared/Stack/convolution_1/BiasAdd',
#  'shared/Stack/convolution_1/Relu',
#  'shared/Stack/convolution_2/weights',
#  'shared/Stack/convolution_2/weights/Initializer/random_uniform/shape',
#  'shared/Stack/convolution_2/weights/Initializer/random_uniform/min',
#  'shared/Stack/convolution_2/weights/Initializer/random_uniform/max',
#  'shared/Stack/convolution_2/weights/Initializer/random_uniform/RandomUniform',
#  'shared/Stack/convolution_2/weights/Initializer/random_uniform/sub',
#  'shared/Stack/convolution_2/weights/Initializer/random_uniform/mul',
#  'shared/Stack/convolution_2/weights/Initializer/random_uniform',
#  'shared/Stack/convolution_2/weights/Assign',
#  'shared/Stack/convolution_2/weights/read',
#  'shared/Stack/convolution_2/convolution/Shape',
#  'shared/Stack/convolution_2/convolution/dilation_rate',
#  'shared/Stack/convolution_2/convolution/ExpandDims/dim',
#  'shared/Stack/convolution_2/convolution/ExpandDims',
#  'shared/Stack/convolution_2/convolution/ExpandDims_1/dim',
#  'shared/Stack/convolution_2/convolution/ExpandDims_1',
#  'shared/Stack/convolution_2/convolution/Conv2D',
#  'shared/Stack/convolution_2/convolution/Squeeze',
#  'shared/Stack/convolution_2/biases',
#  'shared/Stack/convolution_2/biases/Initializer/zeros',
#  'shared/Stack/convolution_2/biases/Assign',
#  'shared/Stack/convolution_2/biases/read',
#  'shared/Stack/convolution_2/BiasAdd',
#  'shared/Stack/convolution_2/Relu',
#  'shared/Flatten/Reshape/shape',
#  'shared/Flatten/Reshape',
#  'shared/fully_connected/Shape',
#  'shared/fully_connected/unpack',
#  'shared/fully_connected/weights',
#  'shared/fully_connected/weights/Initializer/random_uniform/shape',
#  'shared/fully_connected/weights/Initializer/random_uniform/min',
#  'shared/fully_connected/weights/Initializer/random_uniform/max',
#  'shared/fully_connected/weights/Initializer/random_uniform/RandomUniform',
#  'shared/fully_connected/weights/Initializer/random_uniform/sub',
#  'shared/fully_connected/weights/Initializer/random_uniform/mul',
#  'shared/fully_connected/weights/Initializer/random_uniform',
#  'shared/fully_connected/weights/Assign',
#  'shared/fully_connected/weights/read',
#  'shared/fully_connected/MatMul',
#  'shared/fully_connected/biases',
#  'shared/fully_connected/biases/Initializer/zeros',
#  'shared/fully_connected/biases/Assign',
#  'shared/fully_connected/biases/read',
#  'shared/fully_connected/BiasAdd',
#  'shared/fully_connected/Relu',
#  'policy/fully_connected/Shape',
#  'policy/fully_connected/unpack',
#  'policy/fully_connected/weights',
#  'policy/fully_connected/weights/Initializer/random_uniform/shape',
#  'policy/fully_connected/weights/Initializer/random_uniform/min',
#  'policy/fully_connected/weights/Initializer/random_uniform/max',
#  'policy/fully_connected/weights/Initializer/random_uniform/RandomUniform',
#  'policy/fully_connected/weights/Initializer/random_uniform/sub',
#  'policy/fully_connected/weights/Initializer/random_uniform/mul',
#  'policy/fully_connected/weights/Initializer/random_uniform',
#  'policy/fully_connected/weights/Assign',
#  'policy/fully_connected/weights/read',
#  'policy/fully_connected/MatMul',
#  'policy/fully_connected/biases',
#  'policy/fully_connected/biases/Initializer/zeros',
#  'policy/fully_connected/biases/Assign',
#  'policy/fully_connected/biases/read',
#  'policy/fully_connected/BiasAdd',
#  'policy/fully_connected/Softmax',
#  'Shape',
#  'strided_slice/stack',
#  'strided_slice/stack_1',
#  'strided_slice/stack_2',
#  'strided_slice',
#  'range/start',
#  'range/delta',
#  'range',
#  'Shape_1',
#  'strided_slice_1/stack',
#  'strided_slice_1/stack_1',
#  'strided_slice_1/stack_2',
#  'strided_slice_1',
#  'mul',
#  'add',
#  'Reshape/shape',
#  'Reshape',
#  'Gather',
#  'Log',
#  'mul_1',
#  'Rank',
#  'range_1/start',
#  'range_1/delta',
#  'range_1',
#  'Mean',
#  'Neg',
#  'gradients/Shape',
#  'gradients/Const',
#  'gradients/Fill',
#  'gradients/Neg_grad/Neg',
#  'gradients/Mean_grad/Shape',
#  'gradients/Mean_grad/Size',
#  'gradients/Mean_grad/add',
#  'gradients/Mean_grad/mod',
#  'gradients/Mean_grad/Shape_1',
#  'gradients/Mean_grad/range/start',
#  'gradients/Mean_grad/range/delta',
#  'gradients/Mean_grad/range',
#  'gradients/Mean_grad/Fill/value',
#  'gradients/Mean_grad/Fill',
#  'gradients/Mean_grad/DynamicStitch',
#  'gradients/Mean_grad/Maximum/y',
#  'gradients/Mean_grad/Maximum',
#  'gradients/Mean_grad/floordiv',
#  'gradients/Mean_grad/Reshape',
#  'gradients/Mean_grad/Tile',
#  'gradients/Mean_grad/Shape_2',
#  'gradients/Mean_grad/Shape_3',
#  'gradients/Mean_grad/Const',
#  'gradients/Mean_grad/Prod',
#  'gradients/Mean_grad/Const_1',
#  'gradients/Mean_grad/Prod_1',
#  'gradients/Mean_grad/Maximum_1/y',
#  'gradients/Mean_grad/Maximum_1',
#  'gradients/Mean_grad/floordiv_1',
#  'gradients/Mean_grad/Cast',
#  'gradients/Mean_grad/truediv',
#  'gradients/mul_1_grad/Shape',
#  'gradients/mul_1_grad/Shape_1',
#  'gradients/mul_1_grad/BroadcastGradientArgs',
#  'gradients/mul_1_grad/mul',
#  'gradients/mul_1_grad/Sum',
#  'gradients/mul_1_grad/Reshape',
#  'gradients/mul_1_grad/mul_1',
#  'gradients/mul_1_grad/Sum_1',
#  'gradients/mul_1_grad/Reshape_1',
#  'gradients/mul_1_grad/tuple/group_deps',
#  'gradients/mul_1_grad/tuple/control_dependency',
#  'gradients/mul_1_grad/tuple/control_dependency_1',
#  'gradients/Log_grad/Reciprocal',
#  'gradients/Log_grad/mul',
#  'gradients/Gather_grad/Shape',
#  'gradients/Gather_grad/Size',
#  'gradients/Gather_grad/ExpandDims/dim',
#  'gradients/Gather_grad/ExpandDims',
#  'gradients/Gather_grad/strided_slice/stack',
#  'gradients/Gather_grad/strided_slice/stack_1',
#  'gradients/Gather_grad/strided_slice/stack_2',
#  'gradients/Gather_grad/strided_slice',
#  'gradients/Gather_grad/concat/concat_dim',
#  'gradients/Gather_grad/concat',
#  'gradients/Gather_grad/Reshape',
#  'gradients/Gather_grad/Reshape_1',
#  'gradients/Reshape_grad/Shape',
#  'gradients/Reshape_grad/Reshape/strided_slice/stack',
#  'gradients/Reshape_grad/Reshape/strided_slice/stack_1',
#  'gradients/Reshape_grad/Reshape/strided_slice/stack_2',
#  'gradients/Reshape_grad/Reshape/strided_slice',
#  'gradients/Reshape_grad/Reshape/tensor',
#  'gradients/Reshape_grad/Reshape',
#  'gradients/policy/fully_connected/Softmax_grad/mul',
#  'gradients/policy/fully_connected/Softmax_grad/Sum/reduction_indices',
#  'gradients/policy/fully_connected/Softmax_grad/Sum',
#  'gradients/policy/fully_connected/Softmax_grad/Reshape/shape',
#  'gradients/policy/fully_connected/Softmax_grad/Reshape',
#  'gradients/policy/fully_connected/Softmax_grad/sub',
#  'gradients/policy/fully_connected/Softmax_grad/mul_1',
#  'gradients/policy/fully_connected/BiasAdd_grad/BiasAddGrad',
#  'gradients/policy/fully_connected/BiasAdd_grad/tuple/group_deps',
#  'gradients/policy/fully_connected/BiasAdd_grad/tuple/control_dependency',
#  'gradients/policy/fully_connected/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients/policy/fully_connected/MatMul_grad/MatMul',
#  'gradients/policy/fully_connected/MatMul_grad/MatMul_1',
#  'gradients/policy/fully_connected/MatMul_grad/tuple/group_deps',
#  'gradients/policy/fully_connected/MatMul_grad/tuple/control_dependency',
#  'gradients/policy/fully_connected/MatMul_grad/tuple/control_dependency_1',
#  'gradients/shared/fully_connected/Relu_grad/ReluGrad',
#  'gradients/shared/fully_connected/BiasAdd_grad/BiasAddGrad',
#  'gradients/shared/fully_connected/BiasAdd_grad/tuple/group_deps',
#  'gradients/shared/fully_connected/BiasAdd_grad/tuple/control_dependency',
#  'gradients/shared/fully_connected/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients/shared/fully_connected/MatMul_grad/MatMul',
#  'gradients/shared/fully_connected/MatMul_grad/MatMul_1',
#  'gradients/shared/fully_connected/MatMul_grad/tuple/group_deps',
#  'gradients/shared/fully_connected/MatMul_grad/tuple/control_dependency',
#  'gradients/shared/fully_connected/MatMul_grad/tuple/control_dependency_1',
#  'gradients/shared/Flatten/Reshape_grad/Shape',
#  'gradients/shared/Flatten/Reshape_grad/Reshape',
#  'gradients/shared/Stack/convolution_2/Relu_grad/ReluGrad',
#  'gradients/shared/Stack/convolution_2/BiasAdd_grad/BiasAddGrad',
#  'gradients/shared/Stack/convolution_2/BiasAdd_grad/tuple/group_deps',
#  'gradients/shared/Stack/convolution_2/BiasAdd_grad/tuple/control_dependency',
#  'gradients/shared/Stack/convolution_2/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients/shared/Stack/convolution_2/convolution/Squeeze_grad/Shape',
#  'gradients/shared/Stack/convolution_2/convolution/Squeeze_grad/Reshape',
#  'gradients/shared/Stack/convolution_2/convolution/Conv2D_grad/Shape',
#  'gradients/shared/Stack/convolution_2/convolution/Conv2D_grad/Conv2DBackpropInput',
#  'gradients/shared/Stack/convolution_2/convolution/Conv2D_grad/Shape_1',
#  'gradients/shared/Stack/convolution_2/convolution/Conv2D_grad/Conv2DBackpropFilter',
#  'gradients/shared/Stack/convolution_2/convolution/Conv2D_grad/tuple/group_deps',
#  'gradients/shared/Stack/convolution_2/convolution/Conv2D_grad/tuple/control_dependency',
#  'gradients/shared/Stack/convolution_2/convolution/Conv2D_grad/tuple/control_dependency_1',
#  'gradients/shared/Stack/convolution_2/convolution/ExpandDims_grad/Shape',
#  'gradients/shared/Stack/convolution_2/convolution/ExpandDims_grad/Reshape',
#  'gradients/shared/Stack/convolution_2/convolution/ExpandDims_1_grad/Shape',
#  'gradients/shared/Stack/convolution_2/convolution/ExpandDims_1_grad/Reshape',
#  'gradients/shared/Stack/convolution_1/Relu_grad/ReluGrad',
#  'gradients/shared/Stack/convolution_1/BiasAdd_grad/BiasAddGrad',
#  'gradients/shared/Stack/convolution_1/BiasAdd_grad/tuple/group_deps',
#  'gradients/shared/Stack/convolution_1/BiasAdd_grad/tuple/control_dependency',
#  'gradients/shared/Stack/convolution_1/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients/shared/Stack/convolution_1/convolution/Squeeze_grad/Shape',
#  'gradients/shared/Stack/convolution_1/convolution/Squeeze_grad/Reshape',
#  'gradients/shared/Stack/convolution_1/convolution/Conv2D_grad/Shape',
#  'gradients/shared/Stack/convolution_1/convolution/Conv2D_grad/Conv2DBackpropInput',
#  'gradients/shared/Stack/convolution_1/convolution/Conv2D_grad/Shape_1',
#  'gradients/shared/Stack/convolution_1/convolution/Conv2D_grad/Conv2DBackpropFilter',
#  'gradients/shared/Stack/convolution_1/convolution/Conv2D_grad/tuple/group_deps',
#  'gradients/shared/Stack/convolution_1/convolution/Conv2D_grad/tuple/control_dependency',
#  'gradients/shared/Stack/convolution_1/convolution/Conv2D_grad/tuple/control_dependency_1',
#  'gradients/shared/Stack/convolution_1/convolution/ExpandDims_1_grad/Shape',
#  'gradients/shared/Stack/convolution_1/convolution/ExpandDims_1_grad/Reshape',
#  'global_step',
#  'global_step/Initializer/zeros',
#  'global_step/Assign',
#  'global_step/read',
#  'beta1_power/initial_value',
#  'beta1_power',
#  'beta1_power/Assign',
#  'beta1_power/read',
#  'beta2_power/initial_value',
#  'beta2_power',
#  'beta2_power/Assign',
#  'beta2_power/read',
#  'zeros',
#  'policy/fully_connected/weights/Adam',
#  'policy/fully_connected/weights/Adam/Assign',
#  'policy/fully_connected/weights/Adam/read',
#  'zeros_1',
#  'policy/fully_connected/weights/Adam_1',
#  'policy/fully_connected/weights/Adam_1/Assign',
#  'policy/fully_connected/weights/Adam_1/read',
#  'zeros_2',
#  'policy/fully_connected/biases/Adam',
#  'policy/fully_connected/biases/Adam/Assign',
#  'policy/fully_connected/biases/Adam/read',
#  'zeros_3',
#  'policy/fully_connected/biases/Adam_1',
#  'policy/fully_connected/biases/Adam_1/Assign',
#  'policy/fully_connected/biases/Adam_1/read',
#  'zeros_4',
#  'shared/Stack/convolution_1/weights/Adam',
#  'shared/Stack/convolution_1/weights/Adam/Assign',
#  'shared/Stack/convolution_1/weights/Adam/read',
#  'zeros_5',
#  'shared/Stack/convolution_1/weights/Adam_1',
#  'shared/Stack/convolution_1/weights/Adam_1/Assign',
#  'shared/Stack/convolution_1/weights/Adam_1/read',
#  'zeros_6',
#  'shared/Stack/convolution_1/biases/Adam',
#  'shared/Stack/convolution_1/biases/Adam/Assign',
#  'shared/Stack/convolution_1/biases/Adam/read',
#  'zeros_7',
#  'shared/Stack/convolution_1/biases/Adam_1',
#  'shared/Stack/convolution_1/biases/Adam_1/Assign',
#  'shared/Stack/convolution_1/biases/Adam_1/read',
#  'zeros_8',
#  'shared/Stack/convolution_2/weights/Adam',
#  'shared/Stack/convolution_2/weights/Adam/Assign',
#  'shared/Stack/convolution_2/weights/Adam/read',
#  'zeros_9',
#  'shared/Stack/convolution_2/weights/Adam_1',
#  'shared/Stack/convolution_2/weights/Adam_1/Assign',
#  'shared/Stack/convolution_2/weights/Adam_1/read',
#  'zeros_10',
#  'shared/Stack/convolution_2/biases/Adam',
#  'shared/Stack/convolution_2/biases/Adam/Assign',
#  'shared/Stack/convolution_2/biases/Adam/read',
#  'zeros_11',
#  'shared/Stack/convolution_2/biases/Adam_1',
#  'shared/Stack/convolution_2/biases/Adam_1/Assign',
#  'shared/Stack/convolution_2/biases/Adam_1/read',
#  'zeros_12',
#  'shared/fully_connected/weights/Adam',
#  'shared/fully_connected/weights/Adam/Assign',
#  'shared/fully_connected/weights/Adam/read',
#  'zeros_13',
#  'shared/fully_connected/weights/Adam_1',
#  'shared/fully_connected/weights/Adam_1/Assign',
#  'shared/fully_connected/weights/Adam_1/read',
#  'zeros_14',
#  'shared/fully_connected/biases/Adam',
#  'shared/fully_connected/biases/Adam/Assign',
#  'shared/fully_connected/biases/Adam/read',
#  'zeros_15',
#  'shared/fully_connected/biases/Adam_1',
#  'shared/fully_connected/biases/Adam_1/Assign',
#  'shared/fully_connected/biases/Adam_1/read',
#  'Adam/learning_rate',
#  'Adam/beta1',
#  'Adam/beta2',
#  'Adam/epsilon',
#  'Adam/update_policy/fully_connected/weights/ApplyAdam',
#  'Adam/update_policy/fully_connected/biases/ApplyAdam',
#  'Adam/update_shared/Stack/convolution_1/weights/ApplyAdam',
#  'Adam/update_shared/Stack/convolution_1/biases/ApplyAdam',
#  'Adam/update_shared/Stack/convolution_2/weights/ApplyAdam',
#  'Adam/update_shared/Stack/convolution_2/biases/ApplyAdam',
#  'Adam/update_shared/fully_connected/weights/ApplyAdam',
#  'Adam/update_shared/fully_connected/biases/ApplyAdam',
#  'Adam/mul',
#  'Adam/Assign',
#  'Adam/mul_1',
#  'Adam/Assign_1',
#  'Adam/update',
#  'Adam/value',
#  'Adam',
#  'states_1',
#  'targets',
#  'shared_1/Stack/convolution_1/convolution/Shape',
#  'shared_1/Stack/convolution_1/convolution/dilation_rate',
#  'shared_1/Stack/convolution_1/convolution/ExpandDims/dim',
#  'shared_1/Stack/convolution_1/convolution/ExpandDims',
#  'shared_1/Stack/convolution_1/convolution/ExpandDims_1/dim',
#  'shared_1/Stack/convolution_1/convolution/ExpandDims_1',
#  'shared_1/Stack/convolution_1/convolution/Conv2D',
#  'shared_1/Stack/convolution_1/convolution/Squeeze',
#  'shared_1/Stack/convolution_1/BiasAdd',
#  'shared_1/Stack/convolution_1/Relu',
#  'shared_1/Stack/convolution_2/convolution/Shape',
#  'shared_1/Stack/convolution_2/convolution/dilation_rate',
#  'shared_1/Stack/convolution_2/convolution/ExpandDims/dim',
#  'shared_1/Stack/convolution_2/convolution/ExpandDims',
#  'shared_1/Stack/convolution_2/convolution/ExpandDims_1/dim',
#  'shared_1/Stack/convolution_2/convolution/ExpandDims_1',
#  'shared_1/Stack/convolution_2/convolution/Conv2D',
#  'shared_1/Stack/convolution_2/convolution/Squeeze',
#  'shared_1/Stack/convolution_2/BiasAdd',
#  'shared_1/Stack/convolution_2/Relu',
#  'shared_1/Flatten/Reshape/shape',
#  'shared_1/Flatten/Reshape',
#  'shared_1/fully_connected/Shape',
#  'shared_1/fully_connected/unpack',
#  'shared_1/fully_connected/MatMul',
#  'shared_1/fully_connected/BiasAdd',
#  'shared_1/fully_connected/Relu',
#  'value_net/fully_connected/Shape',
#  'value_net/fully_connected/unpack',
#  'value_net/fully_connected/weights',
#  'value_net/fully_connected/weights/Initializer/random_uniform/shape',
#  'value_net/fully_connected/weights/Initializer/random_uniform/min',
#  'value_net/fully_connected/weights/Initializer/random_uniform/max',
#  'value_net/fully_connected/weights/Initializer/random_uniform/RandomUniform',
#  'value_net/fully_connected/weights/Initializer/random_uniform/sub',
#  'value_net/fully_connected/weights/Initializer/random_uniform/mul',
#  'value_net/fully_connected/weights/Initializer/random_uniform',
#  'value_net/fully_connected/weights/Assign',
#  'value_net/fully_connected/weights/read',
#  'value_net/fully_connected/MatMul',
#  'value_net/fully_connected/biases',
#  'value_net/fully_connected/biases/Initializer/zeros',
#  'value_net/fully_connected/biases/Assign',
#  'value_net/fully_connected/biases/read',
#  'value_net/fully_connected/BiasAdd',
#  'SquaredDifference',
#  'Rank_1',
#  'range_2/start',
#  'range_2/delta',
#  'range_2',
#  'Mean_1',
#  'gradients_1/Shape',
#  'gradients_1/Const',
#  'gradients_1/Fill',
#  'gradients_1/Mean_1_grad/Shape',
#  'gradients_1/Mean_1_grad/Size',
#  'gradients_1/Mean_1_grad/add',
#  'gradients_1/Mean_1_grad/mod',
#  'gradients_1/Mean_1_grad/Shape_1',
#  'gradients_1/Mean_1_grad/range/start',
#  'gradients_1/Mean_1_grad/range/delta',
#  'gradients_1/Mean_1_grad/range',
#  'gradients_1/Mean_1_grad/Fill/value',
#  'gradients_1/Mean_1_grad/Fill',
#  'gradients_1/Mean_1_grad/DynamicStitch',
#  'gradients_1/Mean_1_grad/Maximum/y',
#  'gradients_1/Mean_1_grad/Maximum',
#  'gradients_1/Mean_1_grad/floordiv',
#  'gradients_1/Mean_1_grad/Reshape',
#  'gradients_1/Mean_1_grad/Tile',
#  'gradients_1/Mean_1_grad/Shape_2',
#  'gradients_1/Mean_1_grad/Shape_3',
#  'gradients_1/Mean_1_grad/Const',
#  'gradients_1/Mean_1_grad/Prod',
#  'gradients_1/Mean_1_grad/Const_1',
#  'gradients_1/Mean_1_grad/Prod_1',
#  'gradients_1/Mean_1_grad/Maximum_1/y',
#  'gradients_1/Mean_1_grad/Maximum_1',
#  'gradients_1/Mean_1_grad/floordiv_1',
#  'gradients_1/Mean_1_grad/Cast',
#  'gradients_1/Mean_1_grad/truediv',
#  'gradients_1/SquaredDifference_grad/Shape',
#  'gradients_1/SquaredDifference_grad/Shape_1',
#  'gradients_1/SquaredDifference_grad/BroadcastGradientArgs',
#  'gradients_1/SquaredDifference_grad/scalar',
#  'gradients_1/SquaredDifference_grad/mul',
#  'gradients_1/SquaredDifference_grad/sub',
#  'gradients_1/SquaredDifference_grad/mul_1',
#  'gradients_1/SquaredDifference_grad/Sum',
#  'gradients_1/SquaredDifference_grad/Reshape',
#  'gradients_1/SquaredDifference_grad/Sum_1',
#  'gradients_1/SquaredDifference_grad/Reshape_1',
#  'gradients_1/SquaredDifference_grad/Neg',
#  'gradients_1/SquaredDifference_grad/tuple/group_deps',
#  'gradients_1/SquaredDifference_grad/tuple/control_dependency',
#  'gradients_1/SquaredDifference_grad/tuple/control_dependency_1',
#  'gradients_1/value_net/fully_connected/BiasAdd_grad/BiasAddGrad',
#  'gradients_1/value_net/fully_connected/BiasAdd_grad/tuple/group_deps',
#  'gradients_1/value_net/fully_connected/BiasAdd_grad/tuple/control_dependency',
#  'gradients_1/value_net/fully_connected/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients_1/value_net/fully_connected/MatMul_grad/MatMul',
#  'gradients_1/value_net/fully_connected/MatMul_grad/MatMul_1',
#  'gradients_1/value_net/fully_connected/MatMul_grad/tuple/group_deps',
#  'gradients_1/value_net/fully_connected/MatMul_grad/tuple/control_dependency',
#  'gradients_1/value_net/fully_connected/MatMul_grad/tuple/control_dependency_1',
#  'gradients_1/shared_1/fully_connected/Relu_grad/ReluGrad',
#  'gradients_1/shared_1/fully_connected/BiasAdd_grad/BiasAddGrad',
#  'gradients_1/shared_1/fully_connected/BiasAdd_grad/tuple/group_deps',
#  'gradients_1/shared_1/fully_connected/BiasAdd_grad/tuple/control_dependency',
#  'gradients_1/shared_1/fully_connected/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients_1/shared_1/fully_connected/MatMul_grad/MatMul',
#  'gradients_1/shared_1/fully_connected/MatMul_grad/MatMul_1',
#  'gradients_1/shared_1/fully_connected/MatMul_grad/tuple/group_deps',
#  'gradients_1/shared_1/fully_connected/MatMul_grad/tuple/control_dependency',
#  'gradients_1/shared_1/fully_connected/MatMul_grad/tuple/control_dependency_1',
#  'gradients_1/shared_1/Flatten/Reshape_grad/Shape',
#  'gradients_1/shared_1/Flatten/Reshape_grad/Reshape',
#  'gradients_1/shared_1/Stack/convolution_2/Relu_grad/ReluGrad',
#  'gradients_1/shared_1/Stack/convolution_2/BiasAdd_grad/BiasAddGrad',
#  'gradients_1/shared_1/Stack/convolution_2/BiasAdd_grad/tuple/group_deps',
#  'gradients_1/shared_1/Stack/convolution_2/BiasAdd_grad/tuple/control_dependency',
#  'gradients_1/shared_1/Stack/convolution_2/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Squeeze_grad/Shape',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Squeeze_grad/Reshape',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Conv2D_grad/Shape',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Conv2D_grad/Conv2DBackpropInput',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Conv2D_grad/Shape_1',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Conv2D_grad/Conv2DBackpropFilter',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Conv2D_grad/tuple/group_deps',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Conv2D_grad/tuple/control_dependency',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/Conv2D_grad/tuple/control_dependency_1',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/ExpandDims_grad/Shape',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/ExpandDims_grad/Reshape',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/ExpandDims_1_grad/Shape',
#  'gradients_1/shared_1/Stack/convolution_2/convolution/ExpandDims_1_grad/Reshape',
#  'gradients_1/shared_1/Stack/convolution_1/Relu_grad/ReluGrad',
#  'gradients_1/shared_1/Stack/convolution_1/BiasAdd_grad/BiasAddGrad',
#  'gradients_1/shared_1/Stack/convolution_1/BiasAdd_grad/tuple/group_deps',
#  'gradients_1/shared_1/Stack/convolution_1/BiasAdd_grad/tuple/control_dependency',
#  'gradients_1/shared_1/Stack/convolution_1/BiasAdd_grad/tuple/control_dependency_1',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Squeeze_grad/Shape',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Squeeze_grad/Reshape',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Conv2D_grad/Shape',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Conv2D_grad/Conv2DBackpropInput',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Conv2D_grad/Shape_1',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Conv2D_grad/Conv2DBackpropFilter',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Conv2D_grad/tuple/group_deps',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Conv2D_grad/tuple/control_dependency',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/Conv2D_grad/tuple/control_dependency_1',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/ExpandDims_1_grad/Shape',
#  'gradients_1/shared_1/Stack/convolution_1/convolution/ExpandDims_1_grad/Reshape',
#  'beta1_power_1/initial_value',
#  'beta1_power_1',
#  'beta1_power_1/Assign',
#  'beta1_power_1/read',
#  'beta2_power_1/initial_value',
#  'beta2_power_1',
#  'beta2_power_1/Assign',
#  'beta2_power_1/read',
#  'zeros_16',
#  'value_net/fully_connected/weights/Adam',
#  'value_net/fully_connected/weights/Adam/Assign',
#  'value_net/fully_connected/weights/Adam/read',
#  'zeros_17',
#  'value_net/fully_connected/weights/Adam_1',
#  'value_net/fully_connected/weights/Adam_1/Assign',
#  'value_net/fully_connected/weights/Adam_1/read',
#  'zeros_18',
#  'value_net/fully_connected/biases/Adam',
#  'value_net/fully_connected/biases/Adam/Assign',
#  'value_net/fully_connected/biases/Adam/read',
#  'zeros_19',
#  'value_net/fully_connected/biases/Adam_1',
#  'value_net/fully_connected/biases/Adam_1/Assign',
#  'value_net/fully_connected/biases/Adam_1/read',
#  'zeros_20',
#  'shared/Stack/convolution_1/weights/Adam_2',
#  'shared/Stack/convolution_1/weights/Adam_2/Assign',
#  'shared/Stack/convolution_1/weights/Adam_2/read',
#  'zeros_21',
#  'shared/Stack/convolution_1/weights/Adam_3',
#  'shared/Stack/convolution_1/weights/Adam_3/Assign',
#  'shared/Stack/convolution_1/weights/Adam_3/read',
#  'zeros_22',
#  'shared/Stack/convolution_1/biases/Adam_2',
#  'shared/Stack/convolution_1/biases/Adam_2/Assign',
#  'shared/Stack/convolution_1/biases/Adam_2/read',
#  'zeros_23',
#  'shared/Stack/convolution_1/biases/Adam_3',
#  'shared/Stack/convolution_1/biases/Adam_3/Assign',
#  'shared/Stack/convolution_1/biases/Adam_3/read',
#  'zeros_24',
#  'shared/Stack/convolution_2/weights/Adam_2',
#  'shared/Stack/convolution_2/weights/Adam_2/Assign',
#  'shared/Stack/convolution_2/weights/Adam_2/read',
#  'zeros_25',
#  'shared/Stack/convolution_2/weights/Adam_3',
#  'shared/Stack/convolution_2/weights/Adam_3/Assign',
#  'shared/Stack/convolution_2/weights/Adam_3/read',
#  'zeros_26',
#  'shared/Stack/convolution_2/biases/Adam_2',
#  'shared/Stack/convolution_2/biases/Adam_2/Assign',
#  'shared/Stack/convolution_2/biases/Adam_2/read',
#  'zeros_27',
#  'shared/Stack/convolution_2/biases/Adam_3',
#  'shared/Stack/convolution_2/biases/Adam_3/Assign',
#  'shared/Stack/convolution_2/biases/Adam_3/read',
#  'zeros_28',
#  'shared/fully_connected/weights/Adam_2',
#  'shared/fully_connected/weights/Adam_2/Assign',
#  'shared/fully_connected/weights/Adam_2/read',
#  'zeros_29',
#  'shared/fully_connected/weights/Adam_3',
#  'shared/fully_connected/weights/Adam_3/Assign',
#  'shared/fully_connected/weights/Adam_3/read',
#  'zeros_30',
#  'shared/fully_connected/biases/Adam_2',
#  'shared/fully_connected/biases/Adam_2/Assign',
#  'shared/fully_connected/biases/Adam_2/read',
#  'zeros_31',
#  'shared/fully_connected/biases/Adam_3',
#  'shared/fully_connected/biases/Adam_3/Assign',
#  'shared/fully_connected/biases/Adam_3/read',
#  'Adam_1/learning_rate',
#  'Adam_1/beta1',
#  'Adam_1/beta2',
#  'Adam_1/epsilon',
#  'Adam_1/update_value_net/fully_connected/weights/ApplyAdam',
#  'Adam_1/update_value_net/fully_connected/biases/ApplyAdam',
#  'Adam_1/update_shared/Stack/convolution_1/weights/ApplyAdam',
#  'Adam_1/update_shared/Stack/convolution_1/biases/ApplyAdam',
#  'Adam_1/update_shared/Stack/convolution_2/weights/ApplyAdam',
#  'Adam_1/update_shared/Stack/convolution_2/biases/ApplyAdam',
#  'Adam_1/update_shared/fully_connected/weights/ApplyAdam',
#  'Adam_1/update_shared/fully_connected/biases/ApplyAdam',
#  'Adam_1/mul',
#  'Adam_1/Assign',
#  'Adam_1/mul_1',
#  'Adam_1/Assign_1',
#  'Adam_1/update',
#  'Adam_1/value',
#  'Adam_1']

# %%
with tf.Session() as sess:
    writer = tf.summary.FileWriter('logs/stats/', sess.graph)

# %%
tf.reset_default_graph()
mypolicy = Policy(3e-4)
# Out:
# /home/quazar/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:91: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
with tf.Session() as sess:
    tf.global_variables_initializer().run()
    probs = mypolicy.predict(sess, states[:100])

# %%
probs.shape
# Out:
# (100, 2)

# %%
state = env.reset()
state = preprocess(state)
# Use a black image for first state
states = []
states.append(np.zeros((80, 80)))

# Repeat until episode is finished
for i_step in itertools.count():
#    action_probs = policy.predict(sess, states[-1])    
    next_state, reward, done, _ = env.step(2)
    next_state = preprocess(next_state)
    states.append(next_state - state)
    #Update state
    if done:
        break    
    state = next_state
    
states = np.array(states)

# %%
plt.imshow(states[259], cmap='gray')
